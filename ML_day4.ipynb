# %% [markdown]
# <a href="https://colab.research.google.com/github/mohitsharmas97/ML_notebooks/blob/main/ML_day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-82f79b18-2504-4f62-8018-f0ffa4259c91" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-82f79b18-2504-4f62-8018-f0ffa4259c91">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataset=pd.read_csv('electric_vehicles_spec_2025.csv.csv')
dataset.head(3)
# Out:
#     brand                model  top_speed_kmh  battery_capacity_kWh  \
# 0  Abarth     500e Convertible            155                  37.8
# 1  Abarth       500e Hatchback            155                  37.8
# 2  Abarth  600e Scorpionissima            200                  50.8
#
#   battery_type  number_of_cells  torque_nm  efficiency_wh_per_km  range_km  \
# 0  Lithium-ion            192.0      235.0                   156       225
# 1  Lithium-ion            192.0      235.0                   149       225
# 2  Lithium-ion            102.0      345.0                   158       280
#
#    acceleration_0_100_s  ...  towing_capacity_kg cargo_volume_l  seats  \
# 0                   7.0  ...                 0.0            185      4
# 1                   7.0  ...                 0.0            185      4
# 2                   5.9  ...                 0.0            360      5
#
#   drivetrain       segment length_mm width_mm  height_mm  car_body_type  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand                      478 non-null    object
#  1   model                      477 non-null    object
#  2   top_speed_kmh              478 non-null    int64
#  3   battery_capacity_kWh       478 non-null    float64
#  4   battery_type               478 non-null    object
#  5   number_of_cells            276 non-null    float64
#  6   torque_nm                  471 non-null    float64
#  7   efficiency_wh_per_km       478 non-null    int64
#  8   range_km                   478 non-null    int64
#  9   acceleration_0_100_s       478 non-null    float64
#  10  fast_charging_power_kw_dc  477 non-null    float64
#  11  fast_charge_port           477 non-null    object
#  12  towing_capacity_kg         452 non-null    float64
# ...

# %%
dataset.describe()
# Out:
#        top_speed_kmh  battery_capacity_kWh  number_of_cells    torque_nm  \
# count     478.000000            478.000000       276.000000   471.000000
# mean      185.487448             74.043724       485.293478   498.012739
# std        34.252773             20.331058      1210.819733   241.461128
# min       125.000000             21.300000        72.000000   113.000000
# 25%       160.000000             60.000000       150.000000   305.000000
# 50%       180.000000             76.150000       216.000000   430.000000
# 75%       201.000000             90.600000       324.000000   679.000000
# max       325.000000            118.000000      7920.000000  1350.000000
#
#        efficiency_wh_per_km    range_km  acceleration_0_100_s  \
# count            478.000000  478.000000            478.000000
# mean             162.903766  393.179916              6.882636
# std               34.317532  103.287335              2.730696
# ...

# %%
dataset.shape
# Out:
# (478, 22)

# %%
sns.boxplot(x="number_of_cells",data=dataset)
plt.show() #outliers found

# %%
sns.distplot(dataset['number_of_cells'])
plt.show()
# Out:
# /tmp/ipython-input-11-3390467489.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['number_of_cells'])

# %% [markdown]
# we can also found outliers by distribution plot...that is displot.....numberof cells ka curvature jyada hai to outliers hai

# %% [markdown]
# by IQr method remove outliers

# %%
dataset.shape
# Out:
# (478, 22)

# %%
q1=dataset["number_of_cells"].quantile(0.25)
q3=dataset["number_of_cells"].quantile(0.75)
q3
# Out:
# np.float64(324.0)

# %%
IQR=q3-q1

# %%
min_range=q1-(1.5*IQR)
max_range=q3+(1.5*IQR)
min_range,max_range
# Out:
# (np.float64(-111.0), np.float64(585.0))

# %%
new_dataset=dataset[dataset["number_of_cells"]<=max_range]

# %%
new_dataset.shape
# Out:
# (264, 22)

# %%
sns.boxplot(x="number_of_cells",data=new_dataset)
plt.show()

# %% [markdown]
# no outliers are present in this figure

# %% [markdown]
# Outlier removal by Z score
