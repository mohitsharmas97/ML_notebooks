# %% [markdown]
# <a href="https://colab.research.google.com/github/mohitsharmas97/ML_notebooks/blob/main/decission_tree_(regression).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Decision Tree (Regression)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("hussainnasirkhan/multiple-linear-regression-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/multiple-linear-regression-dataset

# %%
cd /kaggle/input/multiple-linear-regression-dataset
# Out:
# /kaggle/input/multiple-linear-regression-dataset

# %%
ls
# Out:
# multiple_linear_regression_dataset.csv

# %%
dataset=pd.read_csv("multiple_linear_regression_dataset.csv")
dataset.head(3)
# Out:
#    age  experience  income
# 0   25           1   30450
# 1   30           3   35670
# 2   47           2   31580

# %%
dataset.isnull().sum()
# Out:
# age           0
# experience    0
# income        0
# dtype: int64

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["experience"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor,plot_tree
regressor=DecisionTreeRegressor()
regressor.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
regressor.score(x_test,y_test)*100,regressor.score(x_train,y_train)*100
# Out:
# (70.1492537313433, 100.0)

# %%
plt.figure(figsize=(10,10))
plot_tree(regressor)
plt.show()
